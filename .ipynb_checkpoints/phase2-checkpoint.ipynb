# %% [markdown]
# # Predicting Diamond Prices
# ## Phase 2: Statistical Modelling

# %% [markdown]
#  **Group Name:** Group 5 demons <br>
#  **Group Member:** <br>
#  Saumya Anand s3931404<br>
#  Nikith Kaluwitharana - s3943409<br>
#  Ritish Kandel - s3947204<br>
#  Jayden Carr - s3900432

# %% [markdown]
# ## Table of Contents
# - [Introduction](#intro)
# - [Statistical Modelling](#sm)
# - [Critique & Limitations](#cl)
# - [Summary & Conclusions](#sc)
# - [References](#References)

# %% [markdown]
# ## Introduction <a id='intro'></a>

# %% [markdown]
# ### Phase 1 Summary

# %% [markdown]
# The accurate prediction of the price of diamonds has many benefits to each stakeholder, which includes; buyers, sellers, businesses and large scale companies. The goal of phase 1 was to help to see if the price could be predicted using multiple linear regression graphs.
#
# While some insights were gained by observing the price in respect to the clarity and carat which showed that as the carat goes higher, and as the clarity is better, the price increases, meaning that the carat and clarity affect the price more so than others where the cuts was opposed to clarity in respect to price where both performed differently for each category they were in, meaning that those two factors together could not determine the price entirely.

# %% [markdown]
# ### Report Overview

# %% [markdown]
# We begin by again preparing the dataset, by cleaning with checks for missing values, a summary of statistics, which includes continuous and categorical features, and fixing column names, we can begin our modeling for phase 2.
#
# To start, we use Ordinary Least Squares to view the full model of the data, which also explains the variance and can predict the residuals. After that we can use this data to plot a graph of actual vs predicted price, we then check that the conditions of the full model are met, we record this in a histogram of frequency vs residual. We then check the residual vs predicted price. After we complete a feature selection to find our p-values.
#
# We then continue onto a reduced model overview, where the y and z variables are removed because of a pr>t of more than 0.05. This followers the same process as above, where the data is checked for the residuals vs frequency.
#
# We then observe the critiques and limits of the multilinear regression and the data we obtain from it. And ending with a summary and conclusion of the whole report.

# %% [markdown]
# ### Overview of Methodology

# %% [markdown]
# In the 2nd phase, the ordinary least squares regression model is used to predict the price based on the characteristics outlined in phase 1 of the report, this is assuming that all of the observations present in the diamonds dataset are independent, meaning that the individual values are not changed upon the factor of another. Also that residuals follow a normal distribution.
#
# Using this, we observe the statistical modeling in this report, determining the price of diamonds using figures 9 and 11, we can see that the predicted price is within the actual price of the diamonds, we can say that this is an accurate model for the price of diamonds.
# We move onto the reduced model next, with the y and z columns will be removed because of a pr>t more than 0.05, then the model will again be predicted against the price of the diamonds, and also the residuals calculated such that they can be mapped against the predicted price.

# %% [markdown]
# ## Data Preparation
# ### Preliminaries

# %% [markdown]
# Firstly we need to import all the modules we will be using throughout this report

# %%
# Importing Modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
import patsy
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline 
# %config InlineBackend.figure_format = 'retina'
plt.style.use("ggplot")
pd.set_option('display.max_columns', None)

# %% [markdown]
# The data we're using is being read directly from the .csv file located at the root folder of this repository

# %%
df = pd.read_csv('Phase2_Group5.csv')
df.sample(10, random_state = 999)
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 38848   0.40      Ideal     I      IF   62.2   56.0  4.75  4.71  2.94   1050
# 9023    1.04      Ideal     H     SI1   61.9   57.0  6.49  6.46  4.01   4515
# 51799   0.75    Premium     D     SI2   60.6   56.0  5.94  5.90  3.59   2415
# 35562   0.35    Premium     G     VS1   61.2   58.0  4.54  4.51  2.77    906
# 18923   1.49  Very Good     G     SI2   62.5   58.0  7.20  7.26  4.52   7773
# 53847   0.71      Ideal     H    VVS1   60.8   56.0  5.75  5.83  3.52   2741
# 848     0.72      Ideal     H    VVS2   60.9   57.0  5.79  5.77  3.52   2869
# 9756    0.90    Premium     G     VS1   62.7   58.0  6.06  6.15  3.83   4661
# 15655   1.04    Premium     F     VS2   59.6   62.0  6.62  6.56  3.93   6278
# 3696    0.72  Very Good     G    VVS2   60.1   60.0  5.79  5.82  3.49   3449

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# We shall first confirm whether the fields use the correct data types

# %%
print(f"Shape of the dataset is {df.shape} \n")
print(f"Data types are below where 'object' indicates a string type: ")
print(df.dtypes)
# Out:
# Shape of the dataset is (53940, 10)
#
# Data types are below where 'object' indicates a string type:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# x          float64
# y          float64
# z          float64
# price        int64
# dtype: object

# %% [markdown]
# ### Missing Values Check

# %%
print(f"\nNumber of missing values for each feature:")
print(df.isnull().sum())
# Out:
# Number of missing values for each feature:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %% [markdown]
# ## Summary Statistics

# %%
from IPython.display import display, HTML
display(HTML('<b>Table 1: Summary of continuous features</b>'))
df.describe(include='int64')
# Out:
# <b>Table 1: Summary of continuous features</b>
#               price
# count  53940.000000
# mean    3932.799722
# std     3989.439738
# min      326.000000
# 25%      950.000000
# 50%     2401.000000
# 75%     5324.250000
# max    18823.000000

# %%
display(HTML('<b>Table 2: Summary of categorical features</b>'))
df.describe(include='object')
# Out:
# <b>Table 2: Summary of categorical features</b>
#           cut  color clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065

# %% [markdown]
# ## Fixing Column Names

# %% [markdown]
# This is done to normalise column names incase some fields have special characters or characters that may need to be omitted

# %%
df.columns = [colname.replace(' ', '_') for colname in list(df.columns)]
df.head()
# Out:
#    carat      cut color clarity  depth  table     x     y     z  price
# 0   0.23    Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43    326
# 1   0.21  Premium     E     SI1   59.8   61.0  3.89  3.84  2.31    326
# 2   0.23     Good     E     VS1   56.9   65.0  4.05  4.07  2.31    327
# 3   0.29  Premium     I     VS2   62.4   58.0  4.20  4.23  2.63    334
# 4   0.31     Good     J     SI2   63.3   58.0  4.34  4.35  2.75    335

# %% [markdown]
# ## Statistical Modelling <a id='sm'></a>

# %% [markdown]
# (Statistical Modelling Section: Details of assumptions check, model selection, plots of residuals, and technical analysis of regression results.)
#
# **NOTE:** The second half of [this](https://github.com/akmand/stats_tutorials/blob/main/regression_case_study_predicting_age_in_census_data.ipynb) regression case study ("Statistical Modeling and Performance Evaluation" Section) will be **very helpful** for this section.

# %% [markdown]
# The modelling process was heavily influenced by the link above. See references.

# %% [markdown]
# ### Full Model Overview

# %% [markdown]
# Firstly we begin by viewing the newly cleaned data

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table     x     y     z  price
# 0   0.23    Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43    326
# 1   0.21  Premium     E     SI1   59.8   61.0  3.89  3.84  2.31    326
# 2   0.23     Good     E     VS1   56.9   65.0  4.05  4.07  2.31    327
# 3   0.29  Premium     I     VS2   62.4   58.0  4.20  4.23  2.63    334
# 4   0.31     Good     J     SI2   63.3   58.0  4.34  4.35  2.75    335

# %% [markdown]
# Typically we would manually add all the independant features, however the average personality of a programmer attests to their laziness and unwillingness to perform manual work, therefore through the use of string functions, we can achieve the same result

# %%
encoded = pd.get_dummies(df, drop_first=True)
encoded.columns = [colname.replace(' ', '_') for colname in list(encoded.columns)]
encoded.head()
formula_string_indep_vars_encoded = ' + '.join(encoded.drop(columns='price').columns)
formula_string_encoded = 'price ~ ' + formula_string_indep_vars_encoded
print('formula_string_encoded: ', formula_string_encoded)
# Out:
# formula_string_encoded:  price ~ carat + depth + table + x + y + z + cut_Good + cut_Ideal + cut_Premium + cut_Very_Good + color_E + color_F + color_G + color_H + color_I + color_J + clarity_IF + clarity_SI1 + clarity_SI2 + clarity_VS1 + clarity_VS2 + clarity_VVS1 + clarity_VVS2

# %% [markdown]
# The formula string we have currently will do well to fit in an OLS (ordinary least squares) model to our encoded data

# %%
model_full = sm.formula.ols(formula=formula_string_encoded, data=encoded)
model_full_fitted = model_full.fit()
print(model_full_fitted.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.920
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                 2.688e+04
# Date:                Sun, 23 Oct 2022   Prob (F-statistic):               0.00
# Time:                        23:05:19   Log-Likelihood:            -4.5573e+05
# No. Observations:               53940   AIC:                         9.115e+05
# Df Residuals:                   53916   BIC:                         9.117e+05
# Df Model:                          23
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      2184.4774    408.197      5.352      0.000    1384.409    2984.546
# ...

# %% [markdown]
# The full model has an adjusted R-squared value of 0.920, which means that 92% of the variance is explained by the model.

# %% [markdown]
# We can now define a new data frame for actual price vs. predicted price and the residuals for the full model. We can then use that data to plot the predicted values as well as the regression residuals

# %%
residuals_full = pd.DataFrame({'actual': encoded['price'], 
                               'predicted': model_full_fitted.fittedvalues, 
                               'residual': model_full_fitted.resid})
print(residuals_full.head())
residuals_full[residuals_full['actual']>3000]
# Out:
#    actual    predicted     residual
# 0     326 -1346.364288  1672.364288
# 1     326  -664.595411   990.595411
# 2     327   211.107106   115.892894
# 3     334  -830.737177  1164.737177
# 4     335 -3459.224220  3794.224220
#        actual     predicted     residual
# 1536     3001   2448.075406   552.924594
# 1537     3001   2472.250657   528.749343
# 1538     3001   2603.215908   397.784092
# 1539     3001   3312.884108  -311.884108
# 1540     3001   4032.764571 -1031.764571
# ...       ...           ...          ...
# 27745   18803  14404.475751  4398.524249
# 27746   18804  14650.197463  4153.802537
# 27747   18806  11897.354146  6908.645854
# 27748   18818  14933.134559  3884.865441
# 27749   18823  17310.779192  1512.220808
#
# [23604 rows x 3 columns]

# %% [markdown]
# And now we can plot actual price vs. predicted price

# %%
def plot_line(axis, slope, intercept, **kargs):
    xmin, xmax = axis.get_xlim()
    plt.plot([xmin, xmax], [xmin*slope+intercept, xmax*slope+intercept], **kargs)

# Creating scatter plot
plt.scatter(residuals_full['actual'], residuals_full['predicted'], alpha=0.3);
plot_line(axis=plt.gca(), slope=1, intercept=0, c="blue");
plt.xlabel('Actual price');
plt.ylabel('Predicted price');
plt.title('Figure 9: Scatter plot of actual vs. predicted price for the Full Model', fontsize=15);
plt.show();

# %% [markdown]
# From Figure 9, we observe the accuracy of our regression line after recalling it covering 92% of the model.

# %% [markdown]
# We will now check the diagnostics for the full model

# %% [markdown]
# ### Full Model Diagnostic Checks

# %% [markdown]
# Conditions for least squares line
# - the data should follow a linear trend
# - the residuals should be nearly normal
# - the variability of points around the least squares line remains fairly constant
# - the observations should be independent

# %%
sns.set_theme()
plt.hist(residuals_full['residual'], bins =100);
plt.xlabel('Residual');
plt.ylabel('Frequency');
plt.title('Histogram of residuals for Full Model', fontsize=15);
plt.show();

# %% [markdown]
# The distribution of the residuals is nearly normal hence the condition of nearly normal residuals has not been violated.

# %%
plt.scatter(residuals_full['predicted'], residuals_full['residual'], alpha=0.3);
plt.xlabel('Predicted Price');
plt.ylabel('Residuals')
plt.title('Figure 10(a): Scatterplot of residuals vs. predicted price for Full Model', fontsize=15)
plt.show();

# %% [markdown]
# The variance tends to follow a downwards trend as the predicted price increases. It does remain fairly random and oscillate around zero when the predicted price is between 0 and 17000 but after that the oscilattion around zero turns into a straight downwards trend. This model most likely does not satisfy the constant variability of error assumption.

# %%
plt.scatter(residuals_full['actual'], residuals_full['residual'], alpha=0.3);
plt.xlabel('Actual Price');
plt.ylabel('Residuals')
plt.title('Figure 10(b): Scatterplot of residuals vs. actual price for Full Model', fontsize=15)
plt.show();

# %% [markdown]
# The data contains independent observation and it also follows a linear trend as shown in phase 1

# %% [markdown]
# ### Feature Selection

# %% [markdown]
# You can use the code below to to perform backward feature selection using p-values ([credit](https://github.com/akmand/stats_tutorials/blob/main/regression_case_study_predicting_age_in_census_data.ipynb)).

# %%
## create the patsy model description from formula
patsy_description = patsy.ModelDesc.from_formula(formula_string_encoded)

# initialize feature-selected fit to full model
linreg_fit = model_full_fitted

# do backwards elimination using p-values
p_val_cutoff = 0.05

## WARNING 1: The code below assumes that the Intercept term is present in the model.
## WARNING 2: It will work only with main effects and two-way interactions, if any.

print('\nPerforming backwards feature selection using p-values:')

while True:

    print(linreg_fit.summary())

    pval_series = linreg_fit.pvalues.drop(labels='Intercept')
    pval_series = pval_series.sort_values(ascending=False)
    term = pval_series.index[0]
    pval = pval_series[0]
    if (pval < p_val_cutoff):
        break
    term_components = term.split(':')
    print(f'\nRemoving term "{term}" with p-value {pval:.4}')
    if (len(term_components) == 1): ## this is a main effect term
        patsy_description.rhs_termlist.remove(patsy.Term([patsy.EvalFactor(term_components[0])]))    
    else: ## this is an interaction term
        patsy_description.rhs_termlist.remove(patsy.Term([patsy.EvalFactor(term_components[0]), 
                                                        patsy.EvalFactor(term_components[1])]))    
        
    linreg_fit = smf.ols(formula=patsy_description, data=encoded).fit()
    
###
## this is the clean fit after backwards elimination
model_reduced_fitted = smf.ols(formula = patsy_description, data = encoded).fit()
###
    
#########
print("\n***")
print(model_reduced_fitted.summary())
print("***")
print(f"Regression number of terms: {len(model_reduced_fitted.model.exog_names)}")
print(f"Regression F-distribution p-value: {model_reduced_fitted.f_pvalue:.4f}")
print(f"Regression R-squared: {model_reduced_fitted.rsquared:.4f}")
print(f"Regression Adjusted R-squared: {model_reduced_fitted.rsquared_adj:.4f}")
# Out:
# Performing backwards feature selection using p-values:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.920
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                 2.688e+04
# Date:                Sun, 23 Oct 2022   Prob (F-statistic):               0.00
# Time:                        23:05:22   Log-Likelihood:            -4.5573e+05
# No. Observations:               53940   AIC:                         9.115e+05
# Df Residuals:                   53916   BIC:                         9.117e+05
# Df Model:                          23
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Reduced Model Overview

# %% [markdown]
# Overview of your reduced model, including the variables and terms you are using in your model.

# %%
print(model_reduced_fitted.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.920
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                 2.944e+04
# Date:                Sun, 23 Oct 2022   Prob (F-statistic):               0.00
# Time:                        23:05:22   Log-Likelihood:            -4.5573e+05
# No. Observations:               53940   AIC:                         9.115e+05
# Df Residuals:                   53918   BIC:                         9.117e+05
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      2366.0858    390.351      6.061      0.000    1600.995    3131.177
# ...

# %%
residuals_reduced = pd.DataFrame({'actual': encoded['price'], 
                               'predicted': model_reduced_fitted.fittedvalues, 
                               'residual': model_reduced_fitted.resid})

# %%
def plot_line(axis, slope, intercept, **kargs):
    xmin, xmax = axis.get_xlim()
    plt.plot([xmin, xmax], [xmin*slope+intercept, xmax*slope+intercept], **kargs)

# Creating scatter plot
plt.scatter(residuals_reduced['actual'], residuals_reduced['predicted'], alpha=0.3);
plot_line(axis=plt.gca(), slope=1, intercept=0, c="red");
plt.xlabel('Actual price');
plt.ylabel('Predicted price');
plt.title('Figure 11: Scatter plot of actual vs. predicted price for the Reduced Model', fontsize=15);
plt.show();

# %% [markdown]
# ### Reduced Model Diagnostic Checks

# %%
sns.set_theme()
plt.hist(residuals_reduced['residual'], bins =100);
plt.xlabel('Residual');
plt.ylabel('Frequency');
plt.title('Figure 12a. Histogram of residuals for reduced Model', fontsize=15);
plt.show();

# %%
plt.scatter(residuals_reduced['predicted'], residuals_reduced['residual'], alpha=0.3);
plt.xlabel('Predicted price');
plt.ylabel('Residuals')
plt.title('Figure 12b: Scatterplot of residuals vs. predicted price for reduced Model', fontsize=15)
plt.show();

# %% [markdown]
# The variance is error graph is also similar to the full model graph hence suggesting that the assumption of constant variance may not be being met

# %%
plt.scatter(residuals_reduced['actual'], residuals_reduced['residual'], alpha=0.3);
plt.xlabel('Actual Price');
plt.ylabel('Residuals')
plt.title('Figure 12(c): Scatterplot of residuals vs. actual price for reduced Model', fontsize=15)
plt.show();

# %% [markdown]
# ## Critique & Limitations <a id='cl'></a>

# %% [markdown]
# A limitation of the methodology is that while it allows for prediction based on all explanatory variables within the the dataset. It does not allow us to see the effect of each explanatory variable. This can be done using simple linear regression. A critique for the modelling process is that it yielded in residuals which did not vary constantly hence the assumption may not be satisfied. This could be due to a fault in the process.
#
# Some of the data observed could not be used in the graphs in the reports, as the legends would be unreadable, <br>
# Advantage:<br>
# The multi-linear regression allows the data to determine a single variable based on the whole dataset,<br>
# it also helps identify outliers, as the table, x, y and z did not have much of an impact of the price.<br>
# Disadvantages:<br>
# The model only allows a single line prediction, it assumes a straight line relationship between the price and the variables outliers can skew the data so it may not fit the model

# %% [markdown]
# ## Summary & Conclusions <a id='sc'></a>

# %% [markdown]
# ### Project Summary

# %% [markdown]
# A comprehensive summary of your entire project (both Phase 1 and Phase 2). That is, what exactly did you do in your project? (Example: I first cleaned the data in such and such ways. And then I applied multiple linear regression techniques in such and such ways. etc).

# %% [markdown]
# ### Summary of Findings

# %% [markdown]
# Diagnostic checks with residual  plots indicate that they do not satisfy the constant variability of error assumptions. This pattern indicates that the constant variability assumption of linear regression is not quite satisfied in this case. On the other hand, residual histograms suggest that the assumption of the residuals being normal is true.
#
# The full model has an adjusted R-squared value of 0.920, which means that 92% of the variance is explained by the model. So, it appears that the variables we used are adequate for accurately predicting the price of diamonds within a multiple linear regression framework. The next step would be to add more interaction terms and perhaps some higher order words to see whether the Adjusted R-squared value will improve as a result. But it's possible that a neural network or another nonlinear model may be better suited to the job at hand than a linear regression model.

# %% [markdown]
# ### Conclusions

# %% [markdown]
# Our regression model appears to predict price of diamonds incorrectly for diamonds whose actual price is <500. It is obvious that the model cannot be used for any practical applications with such a large margin of error. Furthermore, there are several quite substantial problems with our model.

# %% [markdown]
# ### References

# %% [markdown]
# Stats_Tutorials/Regression_Case_Study_Predicting_Age_In_Census_Data.Ipynb At Main Akmand/Stats_Tutorials [Online]. Available at: https://github.com/akmand/stats_tutorials/blob/main/regression_case_study_predicting_age_in_census_data.ipynb (Accessed: 23 October 2022).
